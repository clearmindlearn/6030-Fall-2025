# %%
input_string = input()

input_char = input_string[0]
compare_string = input_string[1:]

num_chars = compare_string.count(input_char)

print(str(num_chars) + " " + input_char, end="")

#if num_chars is not equal to 1:
#    print("'s", end="")
#print("")
# Out:
# n It's a sunny day
# 2 n
