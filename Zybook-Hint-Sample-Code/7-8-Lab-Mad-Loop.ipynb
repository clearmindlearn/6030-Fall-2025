# %%
user_input = input()
tokens = user_input.split()

while tokens[0] != "quit":
    print(f"Eating {tokens[1]} {tokens[0]} a day keeps you happy and healthy.")
    user_input = input()
    tokens = user_input.split()
