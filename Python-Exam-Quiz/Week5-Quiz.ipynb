# %%
fruits_dict={'grape':0.56}
fruits_dict["Lemon"]=0.75
print(fruits_dict)
# Out:
# {'grape': 0.56, 'Lemon': 0.75}

# %%
my_list = ["a","b","c"]
print(len(my_list))
# Out:
# 3

# %%
d = {"cat":3, "dog":4}

# %%
d = {"a":10}
d["b"] = 20
display(d)
d["a"] = 99

print(len(d), d["a"])
# Out:
# {'a': 10, 'b': 20}
# 2 99
