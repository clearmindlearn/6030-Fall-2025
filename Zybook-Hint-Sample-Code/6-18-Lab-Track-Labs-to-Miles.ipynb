# %%
def laps_to_miles(user_laps):
    #your code goes here
    return 0 # for now, this function just returns 0

# %%
if __name__ == "__main__":
    user_laps = float(input())
    num_miles = laps_to_miles(user_laps) # you are supposed to implement the fuction above, laps_to_miles
    print(f"{num_miles:.2f}")
