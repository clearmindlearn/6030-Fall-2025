# %%
def max_magnitude(user_val1, user_val2, user_val3):
    max = user_val1 #initinally assume that user_val1 is the max

    if abs(user_val2) > abs(max):
        max = user_val2

    # fill out the rest
    # Your code goes here

    return max

# %%
if __name__ == "__main__":
    x = int(input())
    y = int(input())
    z = int(input())

    largest_mag = max_magnitude(x, y, z)
    print(largest_mag)
# Out:
# 29
# 3
# 4
# 29
