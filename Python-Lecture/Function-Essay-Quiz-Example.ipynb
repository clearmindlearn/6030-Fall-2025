# %% [markdown]
# Example: write a funciton defitnion add_two which does the following:
#
# -Function name: add_two
#
# -input parameters: two integers (x, y)
#
# -output : returns  the sum of the two input parameters.
#
# -What it does: add the two numbers (x and y)

# %%
#Answer
def add_two (x,y):
  return x+y
