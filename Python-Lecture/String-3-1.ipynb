# %%
#String
#1. array of chars (index starts at 0)
#2. Mutable or Immutable? --> Immutable!!!!
#3. String conccaternation

# %%
st1 = "Hello, Hi"
print(st1[0]) #print the first element
print(st1[8]) #print the last element
print(st1[-1]) #another way to print the last element
# Out:
# H
# i
# i

# %%
#Immutable
st2 = "Hello"
#st2[0] = "K"  --> Error since a string is immutable

st3 = "Hi"
st3 = "Hello"

# %%
st4 = "Hello,"
st5 = "World"
st6 = st4 + " " + st5
print(st6)
# Out:
# Hello, World
