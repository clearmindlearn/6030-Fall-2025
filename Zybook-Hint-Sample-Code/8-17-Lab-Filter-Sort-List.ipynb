# %%
# User inputs string w/ numbers
user_input = input()
# Out:
# 10 -7 4 -33 -6 12 -2

# %%
tokens = user_input.split()  # Split into separate strings

print(tokens)  #Note taht tokens is a list of chars, not numbers!
# Out:
# ['10', '-7', '4', '-33', '-6', '12', '-2']

# %%
# Convert strings to negative integers


input_data = [] #initially empty

#for each element in tokens -Note that tokens a list of strings/chars
#convert it to a number and find out that number is negative.
#If negative, add it to the input_data list.

#use the for-loop




print(input_data)
# Out:
# []

# %%
# Sort the list
#input_data.sort(reverse=True)  #decendomg order

#print(input_data)
# Out:
# [-2, -6, -7, -33]

# %%
for values in input_data:
    print(values, end=" ")
# Out:
# -2 -6 -7 -33
