# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def my_function(param):
  print(param)

arg = 25
my_function(arg)
print (arg)
# Out:
# 25
# 25

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def my_function(param):
  param = 32
  print(param)

arg = 25
my_function(arg)
print (arg)
# Out:
# 32
# 25

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def my_function(param_list):
  param_list[0] =100
  print(param_list)


arg_list = [1,2,3] # mutable object
my_function(arg_list)
print(arg_list)
# Out:
# [100, 2, 3]
# [100, 2, 3]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#What is the output of the following code snippet:

def fx (x, y):
  x = 0 #  local varible to the function fx
  y[2] = 100 # y is a local variable to the function. However, it references the list y created by the main



x = 100 # immutable object (int, float, bloolean, .... --> all immutable objects)
y = [1,2,3] # list & dictionary --> mutable object


# Function fx is called
# note that associates are passed to the function parameters x and y

fx(x,y)

print(x)
print(y)
# Out:
# 100
# [1, 2, 100]
