# %%
item_name = input("Enter food item name:\n")

# FIXME (1): Finish reading price and quantity into variables, then output receipt
item_price = float(input("Enter item price:\n"))
item_quantity = int(input("Enter item quantity:\n"))

print("\nRECEIPT")
print(
    f"{item_quantity} {item_name} @ ${item_price:.2f} = ${item_price*item_quantity:.2f}"
)
total_cost = item_price * item_quantity
print(f"Total cost: ${total_cost:.2f}")
print("\n")

# FIXME (2): Read in a second food item, name, price, and quantity, then output second receipt
item_name2 = input("Enter second food item name:\n")
item_price2 = float(input("Enter item price:\n"))
item_quantity2 = int(input("Enter item quantity:\n"))

print("\nRECEIPT")
print(
    f"{item_quantity} {item_name} @ ${item_price:.2f} = ${item_price*item_quantity:.2f}"
)
print(
    f"{item_quantity2} {item_name2} @ ${item_price2:.2f} = ${item_price2*item_quantity2:.2f}"
)

# total_cost = ?

# print(f"Total cost: ${total_cost:.2f}")



# FIXME (3): Add a gratuity and total with tip to the second receipt
mandatory_gratuity = 0.15
add_gratuity = mandatory_gratuity * total_cost

#print(f"\n15% gratuity: ${add_gratuity:.2f}")
#print(f"Total with tip:....................)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2210829901.py in <cell line: 0>()
# ----> 1 item_name = input("Enter food item name:\n")
#       2
#       3 # FIXME (1): Finish reading price and quantity into variables, then output receipt
#       4 item_price = float(input("Enter item price:\n"))
#       5 item_quantity = int(input("Enter item quantity:\n"))
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...
