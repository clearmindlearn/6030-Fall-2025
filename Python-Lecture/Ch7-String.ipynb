# %%
str = "12345" #string is an arry with index.
#index start at 0
#string --> mutable or immutable --> immutable.

#index
print(str[0])
# Out:
# 1

# %%
# string is immutable
str = "hi"
str = "World" #reference variable is now pointing to a new string object, World

# %%
str = "0123456"

#slicing

str[0:2]

str1 = "World"

str1[1:4] # start at index 0 --> index 3 (4-1 =3)
# Out:
# 'orl'

# %% [markdown]
# ## Section 7.2

# %%
str = "one, two, and three"
new_str = str.replace("one", "four")

new_str
# Out:
# 'four, two, and three'

# %%
str = "one and two"
str.find("two") # return the index of the first occurrence of "Two"
# Out:
# 8

# %%
str = "on one onsemiconductor"
str.count("on") #tetruns the # of times "on" occurs in the string
# Out:
# 4

# %%
"Hellow" == "Hello" #boolean expression --> compare two strings
# Out:
# False

# %%
"A" > "a"
# Out:
# False

# %%
"AA" > "Aa"
# Out:
# False

# %% [markdown]
# ## Section 7.4

# %%
url = "http:/wwww.csusb.edu/IDS"  # string
tokens = url.split("/") #forward slash --> / is a separator
#split retrusn a new object whose type is LIST
tokens
# Out:
# ['http:', 'wwww.csusb.edu', 'IDS']

# %%
url = "http://wwww.csusb.edu/IDS"  # string
tokens = url.split("/") #forward slash --> / is a separator
#split retrusn a new object whose type is LIST
tokens
# Out:
# ['http:', '', 'wwww.csusb.edu', 'IDS']

# %% [markdown]
# #### Joining

# %%
web = ["www", 'csusb.edu', 'ids'] # List
separator = "/"
url = separator.join(web)

url
# Out:
# 'www/csusb.edu/ids'

# %% [markdown]
# ## Lab 7.7

# %% [markdown]
# ##Lab 7.8

# %%
user_input = input()
tokens = user_input.split()

tokens
# Out:
# apples 5
# ['apples', '5']

# %%
while tokens[0] != "quit":
  print ("asdfl;kadjf ")
  user_input = input()
  tokens = user_input

# %%
i = 1
sum = 0

while i <= 6:
    sum = sum + i
    i = i + 2

print (sum)
# Out:
# 9
